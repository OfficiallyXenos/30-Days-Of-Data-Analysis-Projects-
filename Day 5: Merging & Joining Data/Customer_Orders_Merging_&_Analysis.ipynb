# %%
# import the pandas library as pd to work on data
import pandas as pd

# %%
# loading the orders and customers data into pandas for analysis
df_orders, df_customers = map(
    pd.read_csv,
    ['/content/orders.csv', '/content/customers.csv']
    )

# printing the first 5 rows of the two datasets
df_orders.head()
# Out:
#    Order_ID  Customer_ID  Order_Date    Product_Name        Category  \
# 0     10001         5263  2024-07-31          Laptop     Electronics
# 1     10002         3027  2024-12-01          Laptop     Electronics
# 2     10003         4990  2023-11-01  Vacuum Cleaner  Home & Kitchen
# 3     10004         4225  2023-08-26          Comics           Books
# 4     10005         4921  2024-01-26         T-Shirt        Clothing
#
#    Quantity  Unit_Price ($)  Total_Amount ($)
# 0         1          251.96            251.96
# 1         1           10.43             10.43
# 2         5          432.74           2163.70
# 3         3           16.21             48.63
# 4         1           13.43             13.43

# %%
df_customers.head()
# Out:
#    Customer_ID   Name                 Email   Join_Date     Location  \
# 0         2001   Liam  user2001@example.com  2024-09-09      Houston
# 1         2002  David  user2002@example.com  2022-09-15      Chicago
# 2         2003  Mason  user2003@example.com  2022-12-20        Miami
# 3         2004   Emma  user2004@example.com  2023-01-24  Los Angeles
# 4         2005   Liam  user2005@example.com  2023-09-11        Miami
#
#   Membership_Level
# 0           Silver
# 1           Silver
# 2             Gold
# 3         Standard
# 4         Standard

# %%
df_orders.shape, df_customers.shape
# Out:
# ((10000, 8), (5000, 6))

# %% [markdown]
# # 1️⃣ Basic Merging & Joining

# %%
# performing an inner join on the two datasets on the customer_id column
inner_df = pd.merge(df_orders, df_customers, on='Customer_ID')
inner_df.head()

# performing a left join on the same column
left_df = pd.merge(df_orders, df_customers, on='Customer_ID', how='left')
left_df.head()

# performing a right join on the same column
right_df = pd.merge(df_orders, df_customers, on='Customer_ID', how='right')
right_df.head()

# performing an outer join on the same column
outer_df = pd.merge(df_orders, df_customers, on='Customer_ID', how='outer')
outer_df.head()
# Out:
#    Order_ID  Customer_ID  Order_Date Product_Name     Category  Quantity  \
# 0   12588.0         2001  2025-03-18       Tablet  Electronics       2.0
# 1   18148.0         2001  2024-08-15       Tablet  Electronics       3.0
# 2   11868.0         2002  2025-01-07        Jeans     Clothing       5.0
# 3   15298.0         2002  2024-09-03   Foundation       Beauty       1.0
# 4       NaN         2003         NaN          NaN          NaN       NaN
#
#    Unit_Price ($)  Total_Amount ($)   Name                 Email   Join_Date  \
# 0          479.31            958.62   Liam  user2001@example.com  2024-09-09
# 1          100.37            301.11   Liam  user2001@example.com  2024-09-09
# 2          250.81           1254.05  David  user2002@example.com  2022-09-15
# 3          134.02            134.02  David  user2002@example.com  2022-09-15
# 4             NaN               NaN  Mason  user2003@example.com  2022-12-20
#
#   Location Membership_Level
# 0  Houston           Silver
# 1  Houston           Silver
# 2  Chicago           Silver
# 3  Chicago           Silver
# 4    Miami             Gold

# %%
# Merge using Customer_ID and Join_Date for a more detailed customer analysis.
